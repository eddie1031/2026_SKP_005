# %%
# !uv add pandas numpy matplotlib

# %%
# list comprehension
# days = [ _ for _ in range(1,5) ]

days = [ 1, 2, 3, 4, 5 ]
sales = [ 12, 18, 15, 23, 27 ]

print(days)
print(sales)
# Out:
# [1, 2, 3, 4, 5]
# [12, 18, 15, 23, 27]

# %%
import matplotlib.pyplot as plt

plt.plot(days, sales)

plt.show()

# %%
plt.bar(days, sales)
plt.show()
